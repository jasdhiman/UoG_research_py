# %%
#importing resources
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# specifying file location
file = 'D:/Jaskaran_Dhiman/Gully_creek/gully_txtinout/tmpsrf.dat'

# %%
# reading the file
df = pd.read_csv(file, header=None)

# %%
# checking
df.head()
# Out:
#          0
# 0 -6.38621
# 1 -6.38621
# 2 -6.38621
# 3 -6.38621
# 4 -6.38621

# %%
# size
df.shape
# Out:
# (7603131, 1)

# %%
df.loc[3467*3-1]
# Out:
# 0   -15.075295
# Name: 10400, dtype: float64

# %%
hru = 3467 # specifying number of HRUs

# %%
# floor dividing the length of the df by number of HRUs to get an array of values with same value every
# x values are same (x = #HRU)
group_array = np.arange(len(df))//hru

# %%
# grouping the df based on the array created (every x value same) and finding stdev value
df2 = df.groupby(group_array).std()

# %%
df2.head()
# Out:
#               0
# 0  1.746242e-07
# 1  6.918844e-01
# 2  1.304028e+00
# 3  2.213940e-01
# 4  3.959866e-01

# %%
plt.figure(figsize=(20,5))
plt.plot(df2)
plt.xlabel('instance')
plt.ylabel('Standard deviation (deg C)')
plt.legend('stdev')

# %%
x/(6*365.25)
# Out:
# 3469.3730321697467
